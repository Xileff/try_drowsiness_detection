# %%
# import tensorflow as tf
# import cv2
# import os
# import matplotlib.pyplot as plt
# import numpy as np

# Split dataset to train and test folders
import shutil
import glob
from tqdm import tqdm

# %%
print(type(tf))
# Out:
# <class 'module'>

# %%
print(os.listdir('mrlEyes_2018_01'))
# Out:
# ['annotation.txt', 's0001', 's0002', 's0003', 's0004', 's0005', 's0006', 's0007', 's0008', 's0009', 's0010', 's0011', 's0012', 's0013', 's0014', 's0015', 's0016', 's0017', 's0018', 's0019', 's0020', 's0021', 's0022', 's0023', 's0024', 's0025', 's0026', 's0027', 's0028', 's0029', 's0030', 's0031', 's0032', 's0033', 's0034', 's0035', 's0036', 's0037', 'stats_2018_01.ods']

# %%
# raw_dir = "mrlEyes_2018_01"

for dirpath, dirname, filenames in os.walk(raw_dir):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4] == '0':
            shutil.copy(src = dirpath + '/' + i, dst="dataset\closed_eyes")
        elif i.split('_')[4] == '1':
            shutil.copy(src = dirpath + '/' + i, dst="dataset\open_eyes")
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 10257/10257 [00:24<00:00, 413.27it/s]

# %%
img_array = cv2.imread("dataset\closed_eyes\s0014_01853_0_0_0_0_0_01.png", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_array, cmap="gray")

# %%
img_array.shape
# Out:
# (95, 95)

# %%
# datadirectory = "train/" #train dataset
# classes = ["closed_eyes", "open_eyes"]

# for category in classes:
#     path = os.path.join(datadirectory, category)
#     for img in os.listdir(path):
#         img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
#         backtorgb = cv2.cvtColor(img_array, cv2.COLOR_GRAY2RGB)
#         plt.imshow(img_array, cmap="gray")
#         plt.show()
#         x = 2
#         break
#     break

# %%
# img_size = 224

# new_array = cv2.resize(backtorgb, (img_size, img_size))
# plt.imshow(new_array, cmap="gray")
# plt.show()

# %% [markdown]
# # Reading all the images and converting them into an array for data and labels

# %%
# Uses a lot of memory(> 3GB) and crashed pc

# datadirectory = "train/" #train dataset
# classes = ["closed_eyes", "open_eyes"]
# img_size = 224
# training_data = []

# def create_training_data():
#     for category in classes:
#         path = os.path.join(datadirectory, category)
#         class_num = classes.index(category) # 0 or 1
        
#         for img in os.listdir(path):
#             try:
#                 img_array = cv2.imread(os.path.join(path, img),  cv2.IMREAD_GRAYSCALE)
#                 backtorgb = cv2.cvtColor(img_array, cv2.COLOR_GRAY2RGB)
#                 new_array = cv2.resize(backtorgb, (img_size, img_size))
#                 training_data.append([new_array, class_num])
#             except Exception as e:
#                 pass

# %%
# a = [1, 2, 3]
# a.index(2)

# create_training_data()

# %%
# print(training_data)
